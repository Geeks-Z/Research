# %% [markdown]
# ## LoRA_Expert Positon

# %% [markdown]
# ## Inc5

# %%
param_counts_backbone = [414960, 207480, 207480, 69160, 34580,34580]  

accuracies_cifar = [97.43, 97.25, 97.15, 96.23, 94.40,89.46]  
accuracies_inr = [89.01, 88.4, 87.04, 81.32, 79.44,69.38]
accuracies_cub = [94.84,94.26,93.54,94.2,93.06,94.41]
accuracies_vtab = [98.15,97.71,98.21,95.56,95.62,95.56]
accuracies_ina = [72.42,74.55,72.78,63.5,69.68,63.5]
accuracies_omni = [90.56,89.58,88.77,84.52,85.11,84.52]

datasets = [  
    ("CIFAR B0 Inc5", accuracies_cifar),  
    ("IN-R B0 Inc5", accuracies_inr),  
    ("CUB B0 Inc5", accuracies_cub),  
    ("VTAB B0 Inc5", accuracies_vtab), 
    ('IN-A B0 Inc5', accuracies_ina),
    ('OMNI B0 Inc5', accuracies_omni) 
]

# %% [markdown]
# ## Inc10

# %%
accuracies_inr = []
accuracies_cub = []
accuracies_ina = []

# %%
import matplotlib.pyplot as plt
  
marker = ['o', 's', 'D', '^', 'v', '>', '<', 'p', 'h']
colors = ['#EF767A', '#48C0AA', '#ABD0F1', '#DCE9F4', '#E56F5E', '#F19685', '#F6C957', '#FFB77F','#BD514A' ]

# 定义数据点  
positions = ['All', 'Odd Block', 'Even Block', 'Head+Tail','Head','Tail']  
  

plt.figure(dpi=300, figsize=(4, 3))  # 设置图表分辨率和尺寸
i = 0
for name, data in datasets:  
    plt.plot(positions,data,label=name,marker=marker[i],color = colors[i], markersize=2,linewidth=1)  
    i+=1
  
# 设置图表标题和坐标轴标签  
plt.xlabel('Positons', fontsize=8)  
plt.ylabel('Accuracy(%)', fontsize=8)  

plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
  
# 设置图例  
plt.legend(fontsize=5,loc='lower left',ncol=2)  # 设置图例位置 
  
# 显示网格  
plt.grid(True)  
  
# 调整x轴刻度，使数据点更易读  
# plt.xticks(param_counts_backbone, positions, rotation=45)  
  
# 显示图表  
plt.show()
